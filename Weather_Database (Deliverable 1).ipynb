# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=92613634a4f87671f71fbff01a9d76c6

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":current_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | carnarvon
# Processing Record 2 of Set 16 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 16 | meulaboh
# Processing Record 4 of Set 16 | port alfred
# Processing Record 5 of Set 16 | mataura
# Processing Record 6 of Set 16 | arraial do cabo
# Processing Record 7 of Set 16 | kruisfontein
# Processing Record 8 of Set 16 | provideniya
# Processing Record 9 of Set 16 | avarua
# Processing Record 10 of Set 16 | kapaa
# Processing Record 11 of Set 16 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 16 | ilulissat
# Processing Record 13 of Set 16 | mokhsogollokh
# Processing Record 14 of Set 16 | rikitea
# Processing Record 15 of Set 16 | cherskiy
# Processing Record 16 of Set 16 | mount isa
# Processing Record 17 of Set 16 | salvador
# Processing Record 18 of Set 16 | takaka
# Processing Record 19 of Set 16 | kirakira
# Processing Record 20 of Set 16 | jamestown
# Processing Record 21 of Set 16 | pizarro
# Processing Record 22 of Set 16 | biloela
# Processing Record 23 of Set 16 | pandan
# Processing Record 24 of Set 16 | deputatskiy
# Processing Record 25 of Set 16 | atuona
# Processing Record 26 of Set 16 | upernavik
# Processing Record 27 of Set 16 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 16 | busselton
# Processing Record 29 of Set 16 | ponta do sol
# Processing Record 30 of Set 16 | cape town
# Processing Record 31 of Set 16 | ziarat
# Processing Record 32 of Set 16 | ushuaia
# Processing Record 33 of Set 16 | nikolskoye
# Processing Record 34 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 16 | clyde river
# Processing Record 36 of Set 16 | strezhevoy
# Processing Record 37 of Set 16 | vaini
# Processing Record 38 of Set 16 | havre-saint-pierre
# Processing Record 39 of Set 16 | lang son
# Processing Record 40 of Set 16 | hermanus
# Processing Record 41 of Set 16 | vila franca do campo
# Processing Record 42 of Set 16 | albany
# Processing Record 43 of Set 16 | punta arenas
# Processing Record 44 of Set 16 | sorong
# Processing Record 45 of Set 16 | pevek
# Processing Record 46 of Set 16 | lagoa
# Processing Record 47 of Set 16 | aljezur
# Processing Record 48 of Set 16 | moose factory
# Processing Record 49 of Set 16 | picton
# Processing Record 50 of Set 16 | corinto
# Processing Record 1 of Set 17 | khilok
# Processing Record 2 of Set 17 | saint-philippe
# Processing Record 3 of Set 17 | paamiut
# Processing Record 4 of Set 17 | lompoc
# Processing Record 5 of Set 17 | ambilobe
# Processing Record 6 of Set 17 | hobart
# Processing Record 7 of Set 17 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 17 | bredasdorp
# Processing Record 9 of Set 17 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 17 | pisco
# Processing Record 11 of Set 17 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 17 | casper
# Processing Record 13 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 17 | new norfolk
# Processing Record 15 of Set 17 | hithadhoo
# Processing Record 16 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 17 | half moon bay
# Processing Record 18 of Set 17 | barrow
# Processing Record 19 of Set 17 | yellowknife
# Processing Record 20 of Set 17 | klyuchi
# Processing Record 21 of Set 17 | tasiilaq
# Processing Record 22 of Set 17 | sur
# Processing Record 23 of Set 17 | kodiak
# Processing Record 24 of Set 17 | rosarito
# Processing Record 25 of Set 17 | duz
# City not found. Skipping...
# Processing Record 26 of Set 17 | bogovarovo
# Processing Record 27 of Set 17 | garachine
# Processing Record 28 of Set 17 | dubki
# Processing Record 29 of Set 17 | portland
# Processing Record 30 of Set 17 | bethel
# Processing Record 31 of Set 17 | mullaitivu
# City not found. Skipping...
# Processing Record 32 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 17 | severo-kurilsk
# Processing Record 34 of Set 17 | henties bay
# Processing Record 35 of Set 17 | lebu
# Processing Record 36 of Set 17 | ostrovnoy
# Processing Record 37 of Set 17 | qaanaaq
# Processing Record 38 of Set 17 | graaff-reinet
# Processing Record 39 of Set 17 | pombia
# Processing Record 40 of Set 17 | butaritari
# Processing Record 41 of Set 17 | saldanha
# Processing Record 42 of Set 17 | victoria
# Processing Record 43 of Set 17 | san patricio
# Processing Record 44 of Set 17 | amapa
# Processing Record 45 of Set 17 | hilo
# Processing Record 46 of Set 17 | barcelos
# Processing Record 47 of Set 17 | maroua
# Processing Record 48 of Set 17 | mar del plata
# Processing Record 49 of Set 17 | puerto ayora
# Processing Record 50 of Set 17 | hovd
# Processing Record 1 of Set 18 | rapid valley
# Processing Record 2 of Set 18 | salalah
# Processing Record 3 of Set 18 | namibe
# Processing Record 4 of Set 18 | raudeberg
# Processing Record 5 of Set 18 | bluff
# Processing Record 6 of Set 18 | aldan
# Processing Record 7 of Set 18 | mezen
# Processing Record 8 of Set 18 | tayga
# Processing Record 9 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 18 | sundsvall
# Processing Record 11 of Set 18 | northport
# Processing Record 12 of Set 18 | tual
# Processing Record 13 of Set 18 | saint george
# Processing Record 14 of Set 18 | mwinilunga
# Processing Record 15 of Set 18 | sarramea
# Processing Record 16 of Set 18 | nelson bay
# Processing Record 17 of Set 18 | akdepe
# Processing Record 18 of Set 18 | anacortes
# Processing Record 19 of Set 18 | benguela
# Processing Record 20 of Set 18 | cabo san lucas
# Processing Record 21 of Set 18 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 18 | sedelnikovo
# City not found. Skipping...
# Processing Record 23 of Set 18 | williams lake
# Processing Record 24 of Set 18 | baruun-urt
# Processing Record 25 of Set 18 | adrar
# Processing Record 26 of Set 18 | constitucion
# Processing Record 27 of Set 18 | miyako
# Processing Record 28 of Set 18 | dingle
# Processing Record 29 of Set 18 | rundu
# Processing Record 30 of Set 18 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 18 | east london
# Processing Record 32 of Set 18 | ryotsu
# Processing Record 33 of Set 18 | nara
# Processing Record 34 of Set 18 | ridgecrest
# Processing Record 35 of Set 18 | mikhaylovka
# Processing Record 36 of Set 18 | san cristobal
# Processing Record 37 of Set 18 | hereford
# Processing Record 38 of Set 18 | port augusta
# Processing Record 39 of Set 18 | kita
# Processing Record 40 of Set 18 | kutum
# Processing Record 41 of Set 18 | iquique
# Processing Record 42 of Set 18 | nenjiang
# Processing Record 43 of Set 18 | gorontalo
# Processing Record 44 of Set 18 | fukue
# Processing Record 45 of Set 18 | marsh harbour
# Processing Record 46 of Set 18 | saint-louis
# Processing Record 47 of Set 18 | faanui
# Processing Record 48 of Set 18 | nanortalik
# Processing Record 49 of Set 18 | tiznit
# Processing Record 50 of Set 18 | tiksi
# Processing Record 1 of Set 19 | ketchikan
# Processing Record 2 of Set 19 | cabedelo
# Processing Record 3 of Set 19 | guerrero negro
# Processing Record 4 of Set 19 | altay
# Processing Record 5 of Set 19 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 6 of Set 19 | gat
# Processing Record 7 of Set 19 | port lincoln
# Processing Record 8 of Set 19 | labuhan
# Processing Record 9 of Set 19 | mama
# Processing Record 10 of Set 19 | bilibino
# Processing Record 11 of Set 19 | tuktoyaktuk
# Processing Record 12 of Set 19 | pacific grove
# Processing Record 13 of Set 19 | chuy
# Processing Record 14 of Set 19 | xghajra
# City not found. Skipping...
# Processing Record 15 of Set 19 | harper
# Processing Record 16 of Set 19 | puquio
# Processing Record 17 of Set 19 | husavik
# Processing Record 18 of Set 19 | sao joao da barra
# Processing Record 19 of Set 19 | puerto morazan
# Processing Record 20 of Set 19 | boke
# Processing Record 21 of Set 19 | shahrud
# Processing Record 22 of Set 19 | georgetown
# Processing Record 23 of Set 19 | haines junction
# Processing Record 24 of Set 19 | kuytun
# Processing Record 25 of Set 19 | dikson
# Processing Record 26 of Set 19 | kungsbacka
# Processing Record 27 of Set 19 | souillac
# Processing Record 28 of Set 19 | mahon
# Processing Record 29 of Set 19 | avera
# Processing Record 30 of Set 19 | lahan
# Processing Record 31 of Set 19 | khatanga
# Processing Record 32 of Set 19 | massakory
# Processing Record 33 of Set 19 | severomuysk
# Processing Record 34 of Set 19 | ferkessedougou
# Processing Record 35 of Set 19 | palmer
# Processing Record 36 of Set 19 | cayenne
# Processing Record 37 of Set 19 | liman
# Processing Record 38 of Set 19 | muroto
# Processing Record 39 of Set 19 | masallatah
# Processing Record 40 of Set 19 | marsa matruh
# Processing Record 41 of Set 19 | alihe
# Processing Record 42 of Set 19 | anchorage
# Processing Record 43 of Set 19 | mirabad
# Processing Record 44 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 19 | longyearbyen
# Processing Record 46 of Set 19 | marshall
# Processing Record 47 of Set 19 | moa
# Processing Record 48 of Set 19 | okhotsk
# Processing Record 49 of Set 19 | sao filipe
# Processing Record 50 of Set 19 | arenapolis
# Processing Record 1 of Set 20 | saskylakh
# Processing Record 2 of Set 20 | thompson
# Processing Record 3 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 20 | mayo
# Processing Record 5 of Set 20 | jalu
# Processing Record 6 of Set 20 | cap malheureux
# Processing Record 7 of Set 20 | milkovo
# Processing Record 8 of Set 20 | xucheng
# Processing Record 9 of Set 20 | ndele
# Processing Record 10 of Set 20 | sandpoint
# Processing Record 11 of Set 20 | ipueiras
# Processing Record 12 of Set 20 | lasa
# Processing Record 13 of Set 20 | kaoma
# Processing Record 14 of Set 20 | the valley
# Processing Record 15 of Set 20 | asau
# Processing Record 16 of Set 20 | port blair
# Processing Record 17 of Set 20 | yarmouth
# Processing Record 18 of Set 20 | nishihara
# Processing Record 19 of Set 20 | fereydun kenar
# Processing Record 20 of Set 20 | bobigny
# Processing Record 21 of Set 20 | portage
# Processing Record 22 of Set 20 | anadyr
# Processing Record 23 of Set 20 | kerteh
# City not found. Skipping...
# Processing Record 24 of Set 20 | tereze
# Processing Record 25 of Set 20 | port elizabeth
# Processing Record 26 of Set 20 | guanica
# Processing Record 27 of Set 20 | kastamonu
# Processing Record 28 of Set 20 | bud
# Processing Record 29 of Set 20 | rawson
# Processing Record 30 of Set 20 | teknaf
# Processing Record 31 of Set 20 | pangnirtung
# Processing Record 32 of Set 20 | san andres
# Processing Record 33 of Set 20 | sinnamary
# Processing Record 34 of Set 20 | srednekolymsk
# Processing Record 35 of Set 20 | yongchang
# Processing Record 36 of Set 20 | hambantota
# Processing Record 37 of Set 20 | bourges
# Processing Record 38 of Set 20 | ust-nera
# Processing Record 39 of Set 20 | papara
# Processing Record 40 of Set 20 | la ronge
# Processing Record 41 of Set 20 | cidreira
# Processing Record 42 of Set 20 | mahebourg
# Processing Record 43 of Set 20 | flinders
# Processing Record 44 of Set 20 | aksarka
# Processing Record 45 of Set 20 | umba
# Processing Record 46 of Set 20 | otradnyy
# Processing Record 47 of Set 20 | kjollefjord
# Processing Record 48 of Set 20 | coetupo
# City not found. Skipping...
# Processing Record 49 of Set 20 | atar
# Processing Record 50 of Set 20 | codrington
# Processing Record 1 of Set 21 | kavieng
# Processing Record 2 of Set 21 | tura
# Processing Record 3 of Set 21 | ust-kut
# Processing Record 4 of Set 21 | mount gambier
# Processing Record 5 of Set 21 | lavrentiya
# Processing Record 6 of Set 21 | hobyo
# Processing Record 7 of Set 21 | mishan
# Processing Record 8 of Set 21 | novosergiyevka
# Processing Record 9 of Set 21 | vardo
# Processing Record 10 of Set 21 | coihaique
# Processing Record 11 of Set 21 | vestmannaeyjar
# Processing Record 12 of Set 21 | seybaplaya
# Processing Record 13 of Set 21 | coquimbo
# Processing Record 14 of Set 21 | limbazi
# Processing Record 15 of Set 21 | ngunguru
# Processing Record 16 of Set 21 | pirovskoye
# Processing Record 17 of Set 21 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 21 | requena
# Processing Record 19 of Set 21 | balclutha
# Processing Record 20 of Set 21 | puerto escondido
# Processing Record 21 of Set 21 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 21 | doha
# Processing Record 23 of Set 21 | bukama
# Processing Record 24 of Set 21 | matara
# Processing Record 25 of Set 21 | svobodnyy
# Processing Record 26 of Set 21 | malanje
# Processing Record 27 of Set 21 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 21 | whyalla
# Processing Record 29 of Set 21 | mattawa
# Processing Record 30 of Set 21 | kamiiso
# Processing Record 31 of Set 21 | guarapari
# Processing Record 32 of Set 21 | rampur hat
# Processing Record 33 of Set 21 | amudat
# Processing Record 34 of Set 21 | sitka
# Processing Record 35 of Set 21 | asosa
# Processing Record 36 of Set 21 | hauge
# Processing Record 37 of Set 21 | marsciano
# Processing Record 38 of Set 21 | kailua
# Processing Record 39 of Set 21 | basudebpur
# Processing Record 40 of Set 21 | windhoek
# Processing Record 41 of Set 21 | kuminskiy
# Processing Record 42 of Set 21 | mayumba
# Processing Record 43 of Set 21 | tatawin
# Processing Record 44 of Set 21 | lesnoye
# Processing Record 45 of Set 21 | rocha
# Processing Record 46 of Set 21 | vila velha
# Processing Record 47 of Set 21 | silver city
# Processing Record 48 of Set 21 | conceicao do araguaia
# Processing Record 49 of Set 21 | coromandel
# Processing Record 50 of Set 21 | berdigestyakh
# Processing Record 1 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 22 | urengoy
# Processing Record 3 of Set 22 | castro
# Processing Record 4 of Set 22 | grindavik
# Processing Record 5 of Set 22 | revda
# Processing Record 6 of Set 22 | loikaw
# Processing Record 7 of Set 22 | kaitangata
# Processing Record 8 of Set 22 | moyale
# Processing Record 9 of Set 22 | deer lake
# Processing Record 10 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 22 | bambanglipuro
# Processing Record 12 of Set 22 | necochea
# Processing Record 13 of Set 22 | ankang
# Processing Record 14 of Set 22 | kieta
# Processing Record 15 of Set 22 | hasaki
# Processing Record 16 of Set 22 | bambous virieux
# Processing Record 17 of Set 22 | demirci
# Processing Record 18 of Set 22 | arman
# Processing Record 19 of Set 22 | erenhot
# Processing Record 20 of Set 22 | gizo
# Processing Record 21 of Set 22 | yining
# Processing Record 22 of Set 22 | aklavik
# Processing Record 23 of Set 22 | simao
# Processing Record 24 of Set 22 | pacifica
# Processing Record 25 of Set 22 | abu zabad
# Processing Record 26 of Set 22 | nome
# Processing Record 27 of Set 22 | norman wells
# Processing Record 28 of Set 22 | ciudad bolivar
# Processing Record 29 of Set 22 | coari
# Processing Record 30 of Set 22 | fairbanks
# Processing Record 31 of Set 22 | talnakh
# Processing Record 32 of Set 22 | kanniyakumari
# Processing Record 33 of Set 22 | iki-burul
# Processing Record 34 of Set 22 | pochutla
# Processing Record 35 of Set 22 | kralendijk
# Processing Record 36 of Set 22 | luanda
# Processing Record 37 of Set 22 | hamilton
# Processing Record 38 of Set 22 | kalabo
# Processing Record 39 of Set 22 | bac lieu
# Processing Record 40 of Set 22 | rongcheng
# Processing Record 41 of Set 22 | port hawkesbury
# Processing Record 42 of Set 22 | bandar-e lengeh
# Processing Record 43 of Set 22 | santa rita
# Processing Record 44 of Set 22 | doba
# Processing Record 45 of Set 22 | havoysund
# Processing Record 46 of Set 22 | port hedland
# Processing Record 47 of Set 22 | praia da vitoria
# Processing Record 48 of Set 22 | katsuura
# Processing Record 49 of Set 22 | sinsheim
# Processing Record 50 of Set 22 | narsaq
# Processing Record 1 of Set 23 | padang
# Processing Record 2 of Set 23 | kavaratti
# Processing Record 3 of Set 23 | sambava
# Processing Record 4 of Set 23 | skjervoy
# Processing Record 5 of Set 23 | matane
# Processing Record 6 of Set 23 | ipixuna
# Processing Record 7 of Set 23 | san-pedro
# Processing Record 8 of Set 23 | kununurra
# Processing Record 9 of Set 23 | ponta delgada
# Processing Record 10 of Set 23 | brae
# Processing Record 11 of Set 23 | grand gaube
# Processing Record 12 of Set 23 | fort nelson
# Processing Record 13 of Set 23 | fergus falls
# Processing Record 14 of Set 23 | labelle
# Processing Record 15 of Set 23 | roma
# Processing Record 16 of Set 23 | kawalu
# Processing Record 17 of Set 23 | batagay
# Processing Record 18 of Set 23 | mandalgovi
# Processing Record 19 of Set 23 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 23 | bougouni
# Processing Record 21 of Set 23 | escanaba
# Processing Record 22 of Set 23 | jaru
# Processing Record 23 of Set 23 | ningxiang
# Processing Record 24 of Set 23 | oranjemund
# Processing Record 25 of Set 23 | chapais
# Processing Record 26 of Set 23 | nabire
# Processing Record 27 of Set 23 | baikunthpur
# Processing Record 28 of Set 23 | gerede
# Processing Record 29 of Set 23 | ribeira grande
# Processing Record 30 of Set 23 | cururupu
# Processing Record 31 of Set 23 | puno
# Processing Record 32 of Set 23 | ahipara
# Processing Record 33 of Set 23 | kamen-na-obi
# Processing Record 34 of Set 23 | bilma
# Processing Record 35 of Set 23 | seoul
# Processing Record 36 of Set 23 | cartagena
# Processing Record 37 of Set 23 | pozo colorado
# Processing Record 38 of Set 23 | sabang
# Processing Record 39 of Set 23 | port moresby
# Processing Record 40 of Set 23 | melton
# Processing Record 41 of Set 23 | capreol
# Processing Record 42 of Set 23 | taksimo
# Processing Record 43 of Set 23 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 23 | san rafael
# Processing Record 45 of Set 23 | sabla
# Processing Record 46 of Set 23 | marawi
# Processing Record 47 of Set 23 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 23 | maragogi
# Processing Record 49 of Set 23 | caravelas
# Processing Record 50 of Set 23 | omboue
# Processing Record 1 of Set 24 | blonie
# Processing Record 2 of Set 24 | ekhabi
# Processing Record 3 of Set 24 | west fargo
# Processing Record 4 of Set 24 | richard toll
# City not found. Skipping...
# Processing Record 5 of Set 24 | bhola
# Processing Record 6 of Set 24 | baglung
# Processing Record 7 of Set 24 | san felipe
# Processing Record 8 of Set 24 | champerico
# Processing Record 9 of Set 24 | saint-augustin
# Processing Record 10 of Set 24 | klaksvik
# Processing Record 11 of Set 24 | saint-joseph
# Processing Record 12 of Set 24 | huescar
# Processing Record 13 of Set 24 | cockburn town
# Processing Record 14 of Set 24 | grants
# Processing Record 15 of Set 24 | elizabeth city
# Processing Record 16 of Set 24 | kibala
# Processing Record 17 of Set 24 | chokurdakh
# Processing Record 18 of Set 24 | lazaro cardenas
# Processing Record 19 of Set 24 | mumford
# Processing Record 20 of Set 24 | dien bien
# City not found. Skipping...
# Processing Record 21 of Set 24 | sibolga
# Processing Record 22 of Set 24 | broome
# Processing Record 23 of Set 24 | valdivia
# Processing Record 24 of Set 24 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 24 | hirara
# Processing Record 26 of Set 24 | dunedin
# Processing Record 27 of Set 24 | barreirinhas
# Processing Record 28 of Set 24 | mana
# Processing Record 29 of Set 24 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 24 | iqaluit
# Processing Record 31 of Set 24 | mogadishu
# Processing Record 32 of Set 24 | kirensk
# Processing Record 33 of Set 24 | mutis
# Processing Record 34 of Set 24 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 24 | ginir
# Processing Record 36 of Set 24 | valparaiso
# Processing Record 37 of Set 24 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 24 | nuuk
# Processing Record 39 of Set 24 | monduli
# Processing Record 40 of Set 24 | frei paulo
# Processing Record 41 of Set 24 | tamale
# Processing Record 42 of Set 24 | saurimo
# Processing Record 43 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 24 | lubango
# Processing Record 45 of Set 24 | ritchie
# Processing Record 46 of Set 24 | chara
# Processing Record 47 of Set 24 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 24 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 24 | boa vista
# Processing Record 50 of Set 24 | torbay
# Processing Record 1 of Set 25 | kualakapuas
# Processing Record 2 of Set 25 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 25 | pestovo
# Processing Record 4 of Set 25 | vagay
# Processing Record 5 of Set 25 | pa sang
# Processing Record 6 of Set 25 | tuatapere
# Processing Record 7 of Set 25 | ayr
# Processing Record 8 of Set 25 | omsukchan
# Processing Record 9 of Set 25 | tarrafal
# Processing Record 10 of Set 25 | la rioja
# Processing Record 11 of Set 25 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 12 of Set 25 | vanimo
# Processing Record 13 of Set 25 | entre rios
# Processing Record 14 of Set 25 | kaspiysk
# Processing Record 15 of Set 25 | rio grande
# Processing Record 16 of Set 25 | peshkovo
# Processing Record 17 of Set 25 | kargil
# Processing Record 18 of Set 25 | inhambane
# Processing Record 19 of Set 25 | krasnoborsk
# Processing Record 20 of Set 25 | tatarsk
# Processing Record 21 of Set 25 | nouadhibou
# Processing Record 22 of Set 25 | dali
# Processing Record 23 of Set 25 | esperance
# Processing Record 24 of Set 25 | airai
# Processing Record 25 of Set 25 | lebedinyy
# Processing Record 26 of Set 25 | acapulco
# Processing Record 27 of Set 25 | isangel
# Processing Record 28 of Set 25 | san pedro de ycuamandiyu
# Processing Record 29 of Set 25 | magadan
# Processing Record 30 of Set 25 | kahului
# Processing Record 31 of Set 25 | mitsamiouli
# Processing Record 32 of Set 25 | kawardha
# Processing Record 33 of Set 25 | fortuna
# Processing Record 34 of Set 25 | ostersund
# Processing Record 35 of Set 25 | chudniv
# Processing Record 36 of Set 25 | hendijan
# City not found. Skipping...
# Processing Record 37 of Set 25 | arlit
# Processing Record 38 of Set 25 | mikkeli
# Processing Record 39 of Set 25 | kropotkin
# Processing Record 40 of Set 25 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 25 | hokitika
# Processing Record 42 of Set 25 | ambon
# Processing Record 43 of Set 25 | salinopolis
# Processing Record 44 of Set 25 | puri
# Processing Record 45 of Set 25 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 25 | kisangani
# Processing Record 47 of Set 25 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 25 | lorengau
# Processing Record 49 of Set 25 | cam ranh
# Processing Record 50 of Set 25 | arcata
# Processing Record 1 of Set 26 | ericeira
# Processing Record 2 of Set 26 | gamba
# Processing Record 3 of Set 26 | umm jarr
# City not found. Skipping...
# Processing Record 4 of Set 26 | okha
# Processing Record 5 of Set 26 | brownwood
# Processing Record 6 of Set 26 | nemuro
# Processing Record 7 of Set 26 | kaeo
# Processing Record 8 of Set 26 | antofagasta
# Processing Record 9 of Set 26 | yar-sale
# Processing Record 10 of Set 26 | pontoise
# Processing Record 11 of Set 26 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 26 | kaili
# Processing Record 13 of Set 26 | lodi
# Processing Record 14 of Set 26 | labrea
# Processing Record 15 of Set 26 | jiwani
# Processing Record 16 of Set 26 | straumen
# Processing Record 17 of Set 26 | tigil
# Processing Record 18 of Set 26 | sarangani
# Processing Record 19 of Set 26 | rio gallegos
# Processing Record 20 of Set 26 | kudahuvadhoo
# Processing Record 21 of Set 26 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 26 | hvide sande
# Processing Record 23 of Set 26 | nizwa
# Processing Record 24 of Set 26 | pekan
# Processing Record 25 of Set 26 | shakawe
# Processing Record 26 of Set 26 | itoman
# Processing Record 27 of Set 26 | semnan
# Processing Record 28 of Set 26 | nyurba
# Processing Record 29 of Set 26 | juegang
# Processing Record 30 of Set 26 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 26 | maun
# Processing Record 32 of Set 26 | nioro
# Processing Record 33 of Set 26 | angoche
# Processing Record 34 of Set 26 | itarema
# Processing Record 35 of Set 26 | batagay-alyta
# Processing Record 36 of Set 26 | werda
# Processing Record 37 of Set 26 | evensk
# Processing Record 38 of Set 26 | saint-claude
# Processing Record 39 of Set 26 | mumbwa
# Processing Record 40 of Set 26 | iroquois falls
# Processing Record 41 of Set 26 | alice springs
# Processing Record 42 of Set 26 | verkhnevilyuysk
# Processing Record 43 of Set 26 | beloha
# Processing Record 44 of Set 26 | kulhudhuffushi
# Processing Record 45 of Set 26 | vao
# Processing Record 46 of Set 26 | maniitsoq
# Processing Record 47 of Set 26 | namatanai
# Processing Record 48 of Set 26 | olafsvik
# Processing Record 49 of Set 26 | artyom
# Processing Record 50 of Set 26 | ukiah
# Processing Record 1 of Set 27 | kati
# Processing Record 2 of Set 27 | chokwe
# Processing Record 3 of Set 27 | alofi
# Processing Record 4 of Set 27 | shatrovo
# Processing Record 5 of Set 27 | urumqi
# Processing Record 6 of Set 27 | staryy nadym
# Processing Record 7 of Set 27 | karratha
# Processing Record 8 of Set 27 | ust-kuyga
# Processing Record 9 of Set 27 | dakar
# Processing Record 10 of Set 27 | port macquarie
# Processing Record 11 of Set 27 | pires do rio
# Processing Record 12 of Set 27 | totness
# Processing Record 13 of Set 27 | lamu
# Processing Record 14 of Set 27 | estevan
# Processing Record 15 of Set 27 | lovington
# Processing Record 16 of Set 27 | creel
# Processing Record 17 of Set 27 | lincoln
# Processing Record 18 of Set 27 | kenai
# Processing Record 19 of Set 27 | el dorado
# Processing Record 20 of Set 27 | san quintin
# Processing Record 21 of Set 27 | awjilah
# Processing Record 22 of Set 27 | komsomolskiy
# Processing Record 23 of Set 27 | missoula
# Processing Record 24 of Set 27 | van buren
# Processing Record 25 of Set 27 | waipawa
# Processing Record 26 of Set 27 | leshukonskoye
# Processing Record 27 of Set 27 | villa carlos paz
# Processing Record 28 of Set 27 | bocaiuva
# Processing Record 29 of Set 27 | westport
# Processing Record 30 of Set 27 | hami
# Processing Record 31 of Set 27 | te anau
# Processing Record 32 of Set 27 | kindu
# Processing Record 33 of Set 27 | camacupa
# Processing Record 34 of Set 27 | ipil
# Processing Record 35 of Set 27 | radnevo
# Processing Record 36 of Set 27 | gondanglegi
# Processing Record 37 of Set 27 | port keats
# Processing Record 38 of Set 27 | bengkulu
# Processing Record 39 of Set 27 | belaya gora
# Processing Record 40 of Set 27 | banjar
# Processing Record 41 of Set 27 | kuching
# Processing Record 42 of Set 27 | irece
# Processing Record 43 of Set 27 | luderitz
# Processing Record 44 of Set 27 | bandarbeyla
# Processing Record 45 of Set 27 | lixourion
# Processing Record 46 of Set 27 | tsumeb
# Processing Record 47 of Set 27 | zachagansk
# City not found. Skipping...
# Processing Record 48 of Set 27 | urdoma
# Processing Record 49 of Set 27 | terme
# Processing Record 50 of Set 27 | ploemeur
# Processing Record 1 of Set 28 | kankakee
# Processing Record 2 of Set 28 | eureka
# Processing Record 3 of Set 28 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 28 | tessalit
# Processing Record 5 of Set 28 | trairi
# Processing Record 6 of Set 28 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 28 | san antonio
# Processing Record 8 of Set 28 | ramat yishay
# Processing Record 9 of Set 28 | fevralsk
# City not found. Skipping...
# Processing Record 10 of Set 28 | cruz grande
# Processing Record 11 of Set 28 | samarai
# Processing Record 12 of Set 28 | dauphin
# Processing Record 13 of Set 28 | umm kaddadah
# Processing Record 14 of Set 28 | torit
# Processing Record 15 of Set 28 | burica
# City not found. Skipping...
# Processing Record 16 of Set 28 | yulara
# Processing Record 17 of Set 28 | marathon
# Processing Record 18 of Set 28 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 28 | bardiyah
# Processing Record 20 of Set 28 | wanaka
# Processing Record 21 of Set 28 | sao luiz gonzaga
# Processing Record 22 of Set 28 | qaqortoq
# Processing Record 23 of Set 28 | labuan
# Processing Record 24 of Set 28 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 28 | akureyri
# Processing Record 26 of Set 28 | boguchany
# Processing Record 27 of Set 28 | ocosingo
# Processing Record 28 of Set 28 | navolato
# Processing Record 29 of Set 28 | geraldton
# Processing Record 30 of Set 28 | mattoon
# Processing Record 31 of Set 28 | turkistan
# Processing Record 32 of Set 28 | iracoubo
# Processing Record 33 of Set 28 | tutoia
# Processing Record 34 of Set 28 | urubicha
# Processing Record 35 of Set 28 | plettenberg bay
# Processing Record 36 of Set 28 | sechura
# Processing Record 37 of Set 28 | touros
# Processing Record 38 of Set 28 | huarmey
# Processing Record 39 of Set 28 | sakaiminato
# Processing Record 40 of Set 28 | mocuba
# Processing Record 41 of Set 28 | krasnousolskiy
# City not found. Skipping...
# Processing Record 42 of Set 28 | griffith
# Processing Record 43 of Set 28 | volodarka
# Processing Record 44 of Set 28 | novaya ladoga
# Processing Record 45 of Set 28 | jiazi
# Processing Record 46 of Set 28 | marzuq
# Processing Record 47 of Set 28 | luau
# Processing Record 48 of Set 28 | muzhi
# Processing Record 49 of Set 28 | bathsheba
# Processing Record 50 of Set 28 | waingapu
# Processing Record 1 of Set 29 | aberdeen
# Processing Record 2 of Set 29 | cacapava do sul
# Processing Record 3 of Set 29 | makakilo city
# Processing Record 4 of Set 29 | xuddur
# Processing Record 5 of Set 29 | comodoro rivadavia
# Processing Record 6 of Set 29 | ust-ilimsk
# Processing Record 7 of Set 29 | vostok
# Processing Record 8 of Set 29 | sarkand
# Processing Record 9 of Set 29 | peterhead
# Processing Record 10 of Set 29 | aitape
# Processing Record 11 of Set 29 | cserkeszolo
# Processing Record 12 of Set 29 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 29 | opuwo
# Processing Record 14 of Set 29 | thilogne
# City not found. Skipping...
# Processing Record 15 of Set 29 | hofn
# Processing Record 16 of Set 29 | vangaindrano
# Processing Record 17 of Set 29 | belize
# Processing Record 18 of Set 29 | payo
# Processing Record 19 of Set 29 | amod
# Processing Record 20 of Set 29 | bury saint edmunds
# City not found. Skipping...
# Processing Record 21 of Set 29 | port-gentil
# Processing Record 22 of Set 29 | yeniseysk
# Processing Record 23 of Set 29 | talara
# Processing Record 24 of Set 29 | elat
# Processing Record 25 of Set 29 | manzhouli
# Processing Record 26 of Set 29 | alvorada
# Processing Record 27 of Set 29 | poum
# Processing Record 28 of Set 29 | torbat-e jam
# Processing Record 29 of Set 29 | wanning
# Processing Record 30 of Set 29 | lucapa
# Processing Record 31 of Set 29 | hualmay
# Processing Record 32 of Set 29 | sanming
# Processing Record 33 of Set 29 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 29 | lahaina
# Processing Record 35 of Set 29 | nianzishan
# Processing Record 36 of Set 29 | lianzhou
# Processing Record 37 of Set 29 | mackay
# Processing Record 38 of Set 29 | snasa
# Processing Record 39 of Set 29 | shimoda
# Processing Record 40 of Set 29 | naze
# Processing Record 41 of Set 29 | ancud
# Processing Record 42 of Set 29 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 29 | tiarei
# Processing Record 44 of Set 29 | soe
# Processing Record 45 of Set 29 | xining
# Processing Record 46 of Set 29 | san pedro de cajas
# Processing Record 47 of Set 29 | diego de almagro
# Processing Record 48 of Set 29 | vung tau
# Processing Record 49 of Set 29 | tianpeng
# Processing Record 50 of Set 29 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 30 | katherine
# Processing Record 2 of Set 30 | flower mound
# Processing Record 3 of Set 30 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 30 | halifax
# Processing Record 5 of Set 30 | springfield
# Processing Record 6 of Set 30 | beringovskiy
# Processing Record 7 of Set 30 | kathmandu
# Processing Record 8 of Set 30 | gravelbourg
# Processing Record 9 of Set 30 | sola
# Processing Record 10 of Set 30 | gornopravdinsk
# Processing Record 11 of Set 30 | hailar
# Processing Record 12 of Set 30 | saint-georges
# Processing Record 13 of Set 30 | floro
# Processing Record 14 of Set 30 | skovorodino
# Processing Record 15 of Set 30 | itajuba
# Processing Record 16 of Set 30 | northam
# Processing Record 17 of Set 30 | skaelskor
# Processing Record 18 of Set 30 | athabasca
# Processing Record 19 of Set 30 | lumut
# Processing Record 20 of Set 30 | rio grande da serra
# Processing Record 21 of Set 30 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 30 | cedar city
# Processing Record 23 of Set 30 | sidney
# Processing Record 24 of Set 30 | mayor pablo lagerenza
# Processing Record 25 of Set 30 | neryungri
# Processing Record 26 of Set 30 | huntsville
# Processing Record 27 of Set 30 | peniche
# Processing Record 28 of Set 30 | bhiwandi
# Processing Record 29 of Set 30 | bumbuna
# Processing Record 30 of Set 30 | russell
# Processing Record 31 of Set 30 | great falls
# Processing Record 32 of Set 30 | arkhara
# Processing Record 33 of Set 30 | cierna nad tisou
# Processing Record 34 of Set 30 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 35 of Set 30 | houma
# Processing Record 36 of Set 30 | sistranda
# Processing Record 37 of Set 30 | daru
# Processing Record 38 of Set 30 | eenhana
# Processing Record 39 of Set 30 | aasiaat
# Processing Record 40 of Set 30 | north battleford
# Processing Record 41 of Set 30 | kewanee
# Processing Record 42 of Set 30 | bolotnoye
# Processing Record 43 of Set 30 | paragominas
# Processing Record 44 of Set 30 | goulburn
# Processing Record 45 of Set 30 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 30 | khrebtovaya
# Processing Record 47 of Set 30 | khromtau
# Processing Record 48 of Set 30 | druzhba
# Processing Record 49 of Set 30 | srandakan
# Processing Record 50 of Set 30 | barbacoas
# Processing Record 1 of Set 31 | perth
# Processing Record 2 of Set 31 | tazovskiy
# Processing Record 3 of Set 31 | mrakovo
# Processing Record 4 of Set 31 | zhanakorgan
# Processing Record 5 of Set 31 | peleduy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Carnarvon      AU -24.8667  113.6333     71.67        73           0
# 1         Meulaboh      ID   4.1363   96.1285     76.06        88         100
# 2      Port Alfred      ZA -33.5906   26.8910     64.31        63          51
# 3          Mataura      NZ -46.1927  168.8643     46.54        92          86
# 4  Arraial Do Cabo      BR -22.9661  -42.0278     84.16        69           0
# 5     Kruisfontein      ZA -34.0033   24.7314     62.89        64          81
# 6      Provideniya      RU  64.3833 -173.3000      9.68        65           5
# 7           Avarua      CK -21.2078 -159.7750     69.85        78         100
# 8            Kapaa      US  22.0752 -159.3190     75.52        83          20
# 9        Ilulissat      GL  69.2167  -51.1000     10.42        56          20
#
#    Wind Speed Current Description                 Date
# 0       14.97           clear sky  2021-11-23 15:32:58
# 1        8.01     overcast clouds  2021-11-23 15:32:59
# 2       20.83       broken clouds  2021-11-23 15:32:59
# 3        2.57     overcast clouds  2021-11-23 15:32:59
# 4       12.66           clear sky  2021-11-23 15:33:00
# 5       12.17       broken clouds  2021-11-23 15:33:00
# 6        9.69           clear sky  2021-11-23 15:33:00
# 7        1.14     overcast clouds  2021-11-23 15:33:01
# 8        9.22          few clouds  2021-11-23 15:33:01
# 9       26.46          few clouds  2021-11-23 15:33:02

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
